# %%
def get_request(url):
    payload={}
    headers = {}
    return requests.request("GET", url, headers=headers, data=payload) #data url requets
def createFile(img_id):
     fileName = str(img_id)
     img_path_ıd= str(img_path)
     mainFile = f'https://ws-public.interpol.int/notices/v1/red/{img_path_ıd}/images'
     pictureFile = mainFile + '/' + fileName + '.jpg'
     return pictureFile
def Downloads(file_Path,file_Url):
     with open(os.path.join(r'file_Path'), 'wb') as f:
        response = requests.get(file_Url, stream=False)
        if not response.ok:
            print(response)
        for block in response.iter_content(1024):
            if not block:
                break
            f.write(block)                      
def ımg_path_query():
     for i in s.query(Terrorists.entity_id).all():
        img_path=i[0]
        img_path=list(map(str,img_path)) #tuple to str
        return img_path # sqlachemy data query
def entity_ids(p):
    for x in p:
        new_entity_id=x[10]
        new_entity_id=list(map(str,new_entity_id)) #tuple to str
        return new_entity_id        
def persons(response_person):
    forename =response_person.json()['forename']
    sex_id =response_person.json()['sex_id']
    date_of_birth =response_person.json()['date_of_birth'] 
    place_of_birt= response_person.json()['place_of_birth']
    country=response_person.json()['country_of_birth_id']
    weight=response_person.json()['weight']
    height=response_person.json()['height']
    distinguishing_marks =response_person.json()['distinguishing_marks']
    eyes_colors_id=str(response_person.json()['eyes_colors_id'])
    hairs_id=str(response_person.json()['hairs_id'])
    entity_id=response_person.json()['entity_id']
    return[(forename, sex_id,date_of_birth, place_of_birt,country, weight,height,distinguishing_marks,eyes_colors_id,hairs_id,entity_id)] # data extraction
def language_s(response_person):
    lann=response_person.json()['languages_spoken_ids'] or []
    return lann # data extraction
def nation_s(response_person):
    natt= response_person.json()['nationalities'] or []
    return natt # data extraction
def warrant_s(response_person):
     artwnt=response_person.json()['arrest_warrants']
     for a in artwnt:
        issuing_country_id = a['issuing_country_id']
        charge = a['charge']
        charge_translation = a['charge_translation']
        return[(issuing_country_id,charge,charge_translation)]

# %%
 #Updating Interpol terrorist data if it does not match the newly retrieved data "stmt = (update(user_table). where(user_table.c.id == 5). values(name='user #5'))"
def terroroists_table_update(p):
    query=update(Terrorists).where(Terrorists.entity_id==new_entit_id)
    for y in p:
      update_query=s.query(Terrorists).filter(Terrorists.forename==str(y[0]))
      if not update_query :
         query=query.values(forename=str(y[0]))
      updates_query=s.query(Terrorists).filter(Terrorists.sex_id==str(y[1]))
      if not updates_query:
         query=query.values(sex_id=str(y[1]))
      update_queryy=s.query(Terrorists).filter(Terrorists.date_of_birth==str(y[2]))
      if not update_queryy :
         query=query.values(date_of_birth=str(y[2]))
      updatess_query=s.query(Terrorists).filter(Terrorists.place_of_birt==str(y[3]))
      if not updatess_query:
         query=query.values(place_of_birth=str(y[3]))
      update_queryys=s.query(Terrorists).filter(Terrorists.country_of_birth_id==str(y[4]))
      if not update_queryys:
         query=query.values(country_of_birth_id=str(y[4]))
      updatesss_query=s.query(Terrorists).filter(Terrorists.weight==str(y[5]))
      if not updatesss_query:
         query=query.values(weight=str(y[5]))
      update_querry=s.query(Terrorists).filter(Terrorists.height==str(y[6]))
      if not update_querry:
         query=query.values(height=str(y[6]))
      uupdate_query=s.query(Terrorists).filter(Terrorists.distinguishing_marks==str(y[7]))
      if not uupdate_query:
         query=query.values(distinguishing_marks=str(y[7]))
      updatte_query=s.query(Terrorists).filter(Terrorists.eyes_colors_id==str(y[8]))
      if not updatte_query:
         query=query.values(eyes_colors_id=str(y[8]))
      updatee_query=s.query(Terrorists).filter(Terrorists.hairs_id==str(y[9]))
      if not updatee_query:
         query=query.values(hairs_id=str(y[9]))
      query.execution_options(synchronize_session="fetch")
      return s.execute(query)

# %%
from sqlalchemy.sql import exists
def languagess_crud(ln):
    for k in ln:
      q=exists().where(languages.languages_id==Terrorists.id)
      qq=s.query(languages.languages_spoken_ids).filter(q).filter(~languages.languages_spoken_ids.in_(ln)).first() #If languages_id is same as terroroist id and exists in database, filter languages_spoken_id by one
      #query=query.filter(qq.in_(k)) #Is it in query
      if qq:
         #for l in data:
          dataa2=languages(k)
          #l.Interpol_Languages.append(dataa2)  # one to many relationships insert data
          s.add(dataa2) #data add
          try: 
            s.commit() #data save
          except:
            s.rollback() #Empty the database and return an error when it cannot save to the database
      for i in s.query(languages.languages_spoken_ids).all(): #Fetch full languages_spkoen_id from languages table
        queryy=i[0]
        queryy=list(map(str,queryy)) #tuple to str
        queryy=iter(queryy)
     #burada databesede olup requestde olmayanlar var      
      if not next(queryy) in ln:
        del queryy
      return qq
def nationalities_crud(nt):
    for j in nt:
      q=exists().where(Nations.nationalities_id==Terrorists.id)
      qq1=s.query(Nations.nationalities).filter(q).filter(~Nations.nationalities.in_(nt)).first()#Is it in query 
       
      if qq1:
         #for l in data:
          datass= Nations(j)
          #l.Interpol_Nations.append(datass) # one to many relationships insert data
          s.add(datass) #data add
          try: 
            s.commit() #data save
          except:
            s.rollback() #Empty the database and return an error when it cannot save to the database
      for u in s.query(Nations.nationalities).all(): 
        queryyy=u[0]
        queryyy=list(map(str,queryyy)) #tuple to str
        queryyy=iter(queryyy)
     #burada databesede olup requestde olmayanlar var      
      if not next(queryyy) in nt:
        del queryyy
      return qq1    
def arrres_warrants_crud(wr):
     for w in wr:
      data_x,data_y,data_z=w[0],w[1],w[2]
      q=exists().where(Warrants.arrest_warrants_id==Terrorists.id)
      qq=s.query(Warrants.issuing_country_id).filter(q).filter(~Warrants.issuing_country_id.in_(wr[0])).first()
      q_3=s.query(Warrants.charge).filter(q).filter(~Warrants.charge.in_(w)).first()
      q_4=s.query(Warrants.charge_translation).filter(q).filter(~Warrants.charge_translation.in_(w)).first()
      
      if  qq and  q_3 and q_4:
         #for l in data:
          datass=Warrants(data_x,data_y,data_z)
          #l.Interpolarrest_Warrants.append(datass) # one to many relationships insert data
          s.add(datass) # data add
          try: 
           s.commit() #data save
          except:
           s.rollback()  #Empty the database and return an error when it cannot save to the database 
      for er,m,b in s.query(Warrants.issuing_country_id,Warrants.charge,Warrants.charge_translation).all(): 
        query_x,query_y, query_z=er,m,b
        query_x=list(map(str,query_x))
        query_y=list(map(str,query_y))
        query_x=iter(query_x)
        query_y=iter(query_y)
        if query_z is not None:
         query_z=map(str,query_z) # tuple to str
         
     #burada databesede olup requestde olmayanlar var      
      if not next(query_x) in w and not next(query_y) in w and not query_z in w:
         del query_x
         del query_y
         del query_z #delete
      return qq,q_3,q_4         
def pictures_crud(photoss):
   
    for pt in photoss:
      data_l,data_k=pt[0],pt[1]
      q=exists().where(Photo.images_id==Terrorists.id)
      qqq=s.query(Photo.picture_id).filter(q).filter(~Photo.picture_id.in_(photoss)).first()
      q_7=s.query(Photo.picture_url).filter(q).filter(~Photo.picture_url.in_(photoss)).first(  )
     
      if qqq and q_7:
        picturesFile = createFile(img_id)
        picturesDownload=Downloads(picturesFile,img) 
        for l in data:
          datass2=Photo(data_l,data_k,picturesFile)
          #l.Interpol_Teror_Images.append(datass2) # one to many relationships insert data
          s.add(datass2)  #data add
          try: 
           s.commit() #data save
          except:
           s.rollback()  #Empty the database and return an error when it cannot save to the database
      for df,ml in s.query(Photo.picture_id,Photo.picture_url).all(): 
        query_l,query_k=df[0],ml[0]
        query_l=list(map(str,query_l))
        query_k=list(map(str,query_k)) #fetch all photo_id and picture_url from photo table and tuple to str
        query_l=iter(query_l)
        query_k=iter(query_k)
       
     #burada databesede olup requestde olmayanlar var      
      if not next(query_l) in photoss and not next(query_k) in photoss:
        del query_l
        del query_k #If the query is also in the database, find and delete the missing data in the data retrieved with request
      return qqq,q_7

# %%
response = get_request("https://ws-public.interpol.int/notices/v1/red?resultPerPage=20&page=1")
max_page = int(response.json()['total']/20)
for i in range (1,max_page):
    old_page = response.json()['query']['page']
    url = f"https://ws-public.interpol.int/notices/v1/red?resultPerPage=20&page={i}"
    response = get_request(url)
    new_page = response.json()['query']['page']
    if old_page == new_page and old_page > 1:
        break
    page = len(response.json()['_embedded']['notices'])
    for j in range(0,page):
        person_url = response.json()['_embedded']['notices'][j]['_links']['self']['href']
        ImageUrl =  response.json()['_embedded']['notices'][j]['_links']['images']['href']
        response_person = get_request(person_url)
        response_images= get_request(ImageUrl)
        p=persons(response_person)
        new_entit_id=entity_ids(p)
        new_id=iter(new_entit_id)                      
        ln=language_s(response_person)
        nt= nation_s(response_person)
        wr=warrant_s(response_person)
        img_path=ımg_path_query()
        img_pathh=iter(img_path)
        data=[Terrorists(y[0],y[1],y[2],y[3],y[4],y[5],y[6],y[7],y[8],y[9],y[10]) for y in p]
        data_x=[Warrants(w[0],w[1],w[2])for w in wr]
        for v in response_images.json()['_embedded']['images']:
            img_id=v['picture_id']
            img=v['_links']['self']['href'] 
            photoss=(img_id ,img)
        #update_query= ımg_path_query() #if the entity_id is not in the database, it is called with a query to say add
  
        if next(img_pathh) != next(new_id):
          print("YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY")
          for l in data: 
           for k in ln:
            data1=languages(k)
            l.Interpol_Languages.append(data1)  # one to many relationships insert data 
           for j in nt:
            data2=Nations(j)
            l.Interpol_Nations.append(data2)  # one to many relationships insert data 
           for u in data_x:
            l.Interpolarrest_Warrants.append(u)  # one to many relationships insert data 
           for v in response_images.json()['_embedded']['images']:
            img_id=v['picture_id']
            img=v['_links']['self']['href']
            picturesFile = createFile(img_id)
            picturesDownload=Downloads(picturesFile,img) 
            photos=(img_id ,img)
            data_4= Photo(img_id ,img, picturesFile)
            l.Interpol_Teror_Images.append(data_4) # one to many relationships insert data    
            s.add(l) #data add
            s.add(data1)  #data add
            s.add(data2)  #data add
            s.add(u)  #data add
            s.add(data_4)  #data add
          try: 
            s.commit() #data save
          except:
            s.rollback() #Empty the database and return an error when it cannot save to the database
          finally:
            s.close() #data add finish'''
         
        else:
          map(terroroists_table_update,p)
          languagess_crud(ln) 
          nationalities_crud(nt)
          arrres_warrants_crud(wr)
          pictures_crud(photoss)
          print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
# Out:
# 2022-07-01 13:00:24,694 INFO sqlalchemy.engine.Engine select version()
# 2022-07-01 13:00:24,695 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-01 13:00:24,697 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-07-01 13:00:24,698 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-01 13:00:24,701 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-07-01 13:00:24,701 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-01 13:00:24,704 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:24,727 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:00:24,729 INFO sqlalchemy.engine.Engine [generated in 0.00148s] {}
# 2022-07-01 13:00:24,750 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Languages".languages_id = "Interpol_Terorists".id)) AND ("Interpol_Languages".languages_spoken_ids NOT IN (%(languages_spoken_ids_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:24,752 INFO sqlalchemy.engine.Engine [generated in 0.00222s] {'param_1': 1, 'languages_spoken_ids_1_1': 'SPA'}
# 2022-07-01 13:00:24,770 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-07-01 13:00:24,771 INFO sqlalchemy.engine.Engine [generated in 0.00145s] {'languages_id': None, 'languages_spoken_ids': 'SPA'}
# 2022-07-01 13:00:24,786 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:24,792 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:24,794 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# 2022-07-01 13:00:24,795 INFO sqlalchemy.engine.Engine [generated in 0.00120s] {}
# 2022-07-01 13:00:24,878 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:24,879 INFO sqlalchemy.engine.Engine [generated in 0.00161s] {'param_1': 1, 'nationalities_1_1': 'UY'}
# 2022-07-01 13:00:24,886 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:00:24,887 INFO sqlalchemy.engine.Engine [generated in 0.00114s] {'nationalities_id': None, 'nationalities': 'UY'}
# 2022-07-01 13:00:24,893 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:24,895 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:24,897 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:00:24,899 INFO sqlalchemy.engine.Engine [generated in 0.00154s] {}
# 2022-07-01 13:00:24,913 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:24,915 INFO sqlalchemy.engine.Engine [generated in 0.00136s] {'issuing_country_id_1': 'UY', 'issuing_country_id_2': 'Un Delito de Homicidio, sin perjuicio de la calificación jurídica una vez culminada la indagatoria preliminar, de la cual surgen elementos de la comisión de un presunto delito de comercialización de sustancias estupefacientes prohibidas por la Ley.', 'param_1': 1}
# 2022-07-01 13:00:24,927 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:24,928 INFO sqlalchemy.engine.Engine [generated in 0.00126s] {'charge_1': 'UY', 'charge_2': 'Un Delito de Homicidio, sin perjuicio de la calificación jurídica una vez culminada la indagatoria preliminar, de la cual surgen elementos de la comisión de un presunto delito de comercialización de sustancias estupefacientes prohibidas por la Ley.', 'param_1': 1}
# 2022-07-01 13:00:24,934 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge_translation NOT IN (%(charge_translation_1)s, %(charge_translation_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:24,935 INFO sqlalchemy.engine.Engine [generated in 0.00115s] {'charge_translation_1': 'UY', 'charge_translation_2': 'Un Delito de Homicidio, sin perjuicio de la calificación jurídica una vez culminada la indagatoria preliminar, de la cual surgen elementos de la comisión de un presunto delito de comercialización de sustancias estupefacientes prohibidas por la Ley.', 'param_1': 1}
# 2022-07-01 13:00:24,939 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id", "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge", "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# 2022-07-01 13:00:24,941 INFO sqlalchemy.engine.Engine [generated in 0.00183s] {}
# 2022-07-01 13:00:24,959 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_id NOT IN (%(picture_id_1_1)s, %(picture_id_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:24,961 INFO sqlalchemy.engine.Engine [generated in 0.00176s] {'param_1': 1, 'picture_id_1_1': '62475914', 'picture_id_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-41828/images/62475914'}
# 2022-07-01 13:00:24,969 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_url NOT IN (%(picture_url_1_1)s, %(picture_url_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:24,970 INFO sqlalchemy.engine.Engine [generated in 0.00151s] {'param_1': 1, 'picture_url_1_1': '62475914', 'picture_url_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-41828/images/62475914'}
# 2022-07-01 13:00:26,584 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-07-01 13:00:26,585 INFO sqlalchemy.engine.Engine [generated in 0.00086s] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62475914.jpg"}
# 2022-07-01 13:00:26,589 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:26,592 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:26,593 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:00:26,594 INFO sqlalchemy.engine.Engine [generated in 0.00071s] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2022-07-01 13:00:29,219 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:00:29,220 INFO sqlalchemy.engine.Engine [cached since 4.493s ago] {}
# 2022-07-01 13:00:29,225 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Languages".languages_id = "Interpol_Terorists".id)) AND ("Interpol_Languages".languages_spoken_ids NOT IN (%(languages_spoken_ids_1_1)s, %(languages_spoken_ids_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:29,226 INFO sqlalchemy.engine.Engine [cached since 4.477s ago] {'param_1': 1, 'languages_spoken_ids_1_1': 'ENG', 'languages_spoken_ids_1_2': 'SPA'}
# 2022-07-01 13:00:29,228 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-07-01 13:00:29,229 INFO sqlalchemy.engine.Engine [cached since 4.46s ago] {'languages_id': None, 'languages_spoken_ids': 'ENG'}
# 2022-07-01 13:00:29,231 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:29,233 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:29,234 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# 2022-07-01 13:00:29,235 INFO sqlalchemy.engine.Engine [cached since 4.442s ago] {}
# 2022-07-01 13:00:29,244 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:29,245 INFO sqlalchemy.engine.Engine [cached since 4.368s ago] {'param_1': 1, 'nationalities_1_1': 'BZ'}
# 2022-07-01 13:00:29,248 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:00:29,249 INFO sqlalchemy.engine.Engine [cached since 4.364s ago] {'nationalities_id': None, 'nationalities': 'BZ'}
# 2022-07-01 13:00:29,252 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:29,255 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:29,256 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:00:29,257 INFO sqlalchemy.engine.Engine [cached since 4.36s ago] {}
# 2022-07-01 13:00:29,265 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:29,266 INFO sqlalchemy.engine.Engine [cached since 4.353s ago] {'issuing_country_id_1': 'BZ', 'issuing_country_id_2': 'Murder', 'param_1': 1}
# 2022-07-01 13:00:29,269 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:29,270 INFO sqlalchemy.engine.Engine [cached since 4.344s ago] {'charge_1': 'BZ', 'charge_2': 'Murder', 'param_1': 1}
# 2022-07-01 13:00:29,273 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge_translation NOT IN (%(charge_translation_1)s, %(charge_translation_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:29,275 INFO sqlalchemy.engine.Engine [cached since 4.342s ago] {'charge_translation_1': 'BZ', 'charge_translation_2': 'Murder', 'param_1': 1}
# 2022-07-01 13:00:29,279 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id", "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge", "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# 2022-07-01 13:00:29,280 INFO sqlalchemy.engine.Engine [cached since 4.341s ago] {}
# 2022-07-01 13:00:29,292 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_id NOT IN (%(picture_id_1_1)s, %(picture_id_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:29,293 INFO sqlalchemy.engine.Engine [cached since 4.335s ago] {'param_1': 1, 'picture_id_1_1': '62475867', 'picture_id_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-42117/images/62475867'}
# 2022-07-01 13:00:29,296 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_url NOT IN (%(picture_url_1_1)s, %(picture_url_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:29,297 INFO sqlalchemy.engine.Engine [cached since 4.329s ago] {'param_1': 1, 'picture_url_1_1': '62475867', 'picture_url_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-42117/images/62475867'}
# 2022-07-01 13:00:29,661 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-07-01 13:00:29,662 INFO sqlalchemy.engine.Engine [cached since 3.079s ago] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62475867.jpg"}
# 2022-07-01 13:00:29,664 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:29,667 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:29,669 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:00:29,671 INFO sqlalchemy.engine.Engine [cached since 3.078s ago] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2022-07-01 13:00:30,160 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:00:30,161 INFO sqlalchemy.engine.Engine [cached since 5.433s ago] {}
# 2022-07-01 13:00:30,166 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Languages".languages_id = "Interpol_Terorists".id)) AND ("Interpol_Languages".languages_spoken_ids NOT IN (%(languages_spoken_ids_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:30,167 INFO sqlalchemy.engine.Engine [cached since 5.417s ago] {'param_1': 1, 'languages_spoken_ids_1_1': 'ENG'}
# 2022-07-01 13:00:30,169 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-07-01 13:00:30,170 INFO sqlalchemy.engine.Engine [cached since 5.4s ago] {'languages_id': None, 'languages_spoken_ids': 'ENG'}
# 2022-07-01 13:00:30,173 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:30,175 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:30,177 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# 2022-07-01 13:00:30,179 INFO sqlalchemy.engine.Engine [cached since 5.385s ago] {}
# 2022-07-01 13:00:30,187 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:30,188 INFO sqlalchemy.engine.Engine [cached since 5.31s ago] {'param_1': 1, 'nationalities_1_1': 'IN'}
# 2022-07-01 13:00:30,191 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:00:30,192 INFO sqlalchemy.engine.Engine [cached since 5.306s ago] {'nationalities_id': None, 'nationalities': 'IN'}
# 2022-07-01 13:00:30,203 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:30,205 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:30,206 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:00:30,208 INFO sqlalchemy.engine.Engine [cached since 5.31s ago] {}
# 2022-07-01 13:00:30,219 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:30,220 INFO sqlalchemy.engine.Engine [cached since 5.306s ago] {'issuing_country_id_1': 'MV', 'issuing_country_id_2': 'The case of Omanakuttan Mailadiyil Karunakarakurup, a secondary mathematics teacher has been sexually abusing his student (14 year old) since 2020 on multiple occasions. He escaped from the Maldives while police were investigating the case.', 'param_1': 1}
# 2022-07-01 13:00:30,223 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:30,224 INFO sqlalchemy.engine.Engine [cached since 5.298s ago] {'charge_1': 'MV', 'charge_2': 'The case of Omanakuttan Mailadiyil Karunakarakurup, a secondary mathematics teacher has been sexually abusing his student (14 year old) since 2020 on multiple occasions. He escaped from the Maldives while police were investigating the case.', 'param_1': 1}
# 2022-07-01 13:00:30,229 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge_translation NOT IN (%(charge_translation_1)s, %(charge_translation_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:30,230 INFO sqlalchemy.engine.Engine [cached since 5.296s ago] {'charge_translation_1': 'MV', 'charge_translation_2': 'The case of Omanakuttan Mailadiyil Karunakarakurup, a secondary mathematics teacher has been sexually abusing his student (14 year old) since 2020 on multiple occasions. He escaped from the Maldives while police were investigating the case.', 'param_1': 1}
# 2022-07-01 13:00:30,233 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id", "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge", "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# 2022-07-01 13:00:30,234 INFO sqlalchemy.engine.Engine [cached since 5.295s ago] {}
# 2022-07-01 13:00:30,250 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_id NOT IN (%(picture_id_1_1)s, %(picture_id_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:30,250 INFO sqlalchemy.engine.Engine [cached since 5.291s ago] {'param_1': 1, 'picture_id_1_1': '62474978', 'picture_id_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-41913/images/62474978'}
# 2022-07-01 13:00:30,254 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_url NOT IN (%(picture_url_1_1)s, %(picture_url_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:30,254 INFO sqlalchemy.engine.Engine [cached since 5.286s ago] {'param_1': 1, 'picture_url_1_1': '62474978', 'picture_url_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-41913/images/62474978'}
# 2022-07-01 13:00:30,519 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-07-01 13:00:30,520 INFO sqlalchemy.engine.Engine [cached since 3.937s ago] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62474978.jpg"}
# 2022-07-01 13:00:30,524 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:30,528 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:30,530 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:00:30,532 INFO sqlalchemy.engine.Engine [cached since 3.939s ago] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2022-07-01 13:00:31,022 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:00:31,023 INFO sqlalchemy.engine.Engine [cached since 6.297s ago] {}
# 2022-07-01 13:00:31,031 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,032 INFO sqlalchemy.engine.Engine [cached since 6.155s ago] {'param_1': 1, 'nationalities_1_1': 'BR'}
# 2022-07-01 13:00:31,035 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:00:31,036 INFO sqlalchemy.engine.Engine [cached since 6.151s ago] {'nationalities_id': None, 'nationalities': 'BR'}
# 2022-07-01 13:00:31,038 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:31,040 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:31,042 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:00:31,044 INFO sqlalchemy.engine.Engine [cached since 6.147s ago] {}
# 2022-07-01 13:00:31,054 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,056 INFO sqlalchemy.engine.Engine [cached since 6.143s ago] {'issuing_country_id_1': 'BR', 'issuing_country_id_2': 'Violación de personas vulnerables', 'param_1': 1}
# 2022-07-01 13:00:31,060 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,061 INFO sqlalchemy.engine.Engine [cached since 6.135s ago] {'charge_1': 'BR', 'charge_2': 'Violación de personas vulnerables', 'param_1': 1}
# 2022-07-01 13:00:31,066 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge_translation NOT IN (%(charge_translation_1)s, %(charge_translation_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,067 INFO sqlalchemy.engine.Engine [cached since 6.133s ago] {'charge_translation_1': 'BR', 'charge_translation_2': 'Violación de personas vulnerables', 'param_1': 1}
# 2022-07-01 13:00:31,071 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id", "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge", "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# 2022-07-01 13:00:31,073 INFO sqlalchemy.engine.Engine [cached since 6.134s ago] {}
# 2022-07-01 13:00:31,091 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_id NOT IN (%(picture_id_1_1)s, %(picture_id_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,092 INFO sqlalchemy.engine.Engine [cached since 6.133s ago] {'param_1': 1, 'picture_id_1_1': '62476557', 'picture_id_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-42314/images/62476557'}
# 2022-07-01 13:00:31,097 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_url NOT IN (%(picture_url_1_1)s, %(picture_url_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,098 INFO sqlalchemy.engine.Engine [cached since 6.13s ago] {'param_1': 1, 'picture_url_1_1': '62476557', 'picture_url_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-42314/images/62476557'}
# 2022-07-01 13:00:31,367 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-07-01 13:00:31,368 INFO sqlalchemy.engine.Engine [cached since 4.785s ago] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62476557.jpg"}
# 2022-07-01 13:00:31,370 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:31,372 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:31,374 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:00:31,375 INFO sqlalchemy.engine.Engine [cached since 4.783s ago] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2022-07-01 13:00:31,865 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:00:31,866 INFO sqlalchemy.engine.Engine [cached since 7.139s ago] {}
# 2022-07-01 13:00:31,871 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Languages".languages_id = "Interpol_Terorists".id)) AND ("Interpol_Languages".languages_spoken_ids NOT IN (%(languages_spoken_ids_1_1)s, %(languages_spoken_ids_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,871 INFO sqlalchemy.engine.Engine [cached since 7.122s ago] {'param_1': 1, 'languages_spoken_ids_1_1': 'ENG', 'languages_spoken_ids_1_2': 'CHI'}
# 2022-07-01 13:00:31,874 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-07-01 13:00:31,875 INFO sqlalchemy.engine.Engine [cached since 7.105s ago] {'languages_id': None, 'languages_spoken_ids': 'ENG'}
# 2022-07-01 13:00:31,876 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:31,880 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:31,881 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# 2022-07-01 13:00:31,881 INFO sqlalchemy.engine.Engine [cached since 7.088s ago] {}
# 2022-07-01 13:00:31,889 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,890 INFO sqlalchemy.engine.Engine [cached since 7.013s ago] {'param_1': 1, 'nationalities_1_1': 'CN'}
# 2022-07-01 13:00:31,893 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:00:31,894 INFO sqlalchemy.engine.Engine [cached since 7.008s ago] {'nationalities_id': None, 'nationalities': 'CN'}
# 2022-07-01 13:00:31,897 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:31,899 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:31,900 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:00:31,901 INFO sqlalchemy.engine.Engine [cached since 7.004s ago] {}
# 2022-07-01 13:00:31,909 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,910 INFO sqlalchemy.engine.Engine [cached since 6.997s ago] {'issuing_country_id_1': 'ID', 'issuing_country_id_2': 'Illegal Gold Fencing', 'param_1': 1}
# 2022-07-01 13:00:31,914 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,915 INFO sqlalchemy.engine.Engine [cached since 6.988s ago] {'charge_1': 'ID', 'charge_2': 'Illegal Gold Fencing', 'param_1': 1}
# 2022-07-01 13:00:31,918 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge_translation NOT IN (%(charge_translation_1)s, %(charge_translation_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,919 INFO sqlalchemy.engine.Engine [cached since 6.985s ago] {'charge_translation_1': 'ID', 'charge_translation_2': 'Illegal Gold Fencing', 'param_1': 1}
# 2022-07-01 13:00:31,922 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id", "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge", "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# 2022-07-01 13:00:31,923 INFO sqlalchemy.engine.Engine [cached since 6.984s ago] {}
# 2022-07-01 13:00:31,938 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_id NOT IN (%(picture_id_1_1)s, %(picture_id_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,939 INFO sqlalchemy.engine.Engine [cached since 6.98s ago] {'param_1': 1, 'picture_id_1_1': '62471777', 'picture_id_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-41081/images/62471777'}
# 2022-07-01 13:00:31,944 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_url NOT IN (%(picture_url_1_1)s, %(picture_url_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:31,945 INFO sqlalchemy.engine.Engine [cached since 6.977s ago] {'param_1': 1, 'picture_url_1_1': '62471777', 'picture_url_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-41081/images/62471777'}
# 2022-07-01 13:00:32,331 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-07-01 13:00:32,332 INFO sqlalchemy.engine.Engine [cached since 5.748s ago] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62471777.jpg"}
# 2022-07-01 13:00:32,333 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:32,335 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:32,336 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:00:32,338 INFO sqlalchemy.engine.Engine [cached since 5.745s ago] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2022-07-01 13:00:32,879 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:00:32,880 INFO sqlalchemy.engine.Engine [cached since 8.153s ago] {}
# 2022-07-01 13:00:32,885 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:32,886 INFO sqlalchemy.engine.Engine [cached since 8.009s ago] {'param_1': 1, 'nationalities_1_1': 'NP'}
# 2022-07-01 13:00:32,888 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:00:32,889 INFO sqlalchemy.engine.Engine [cached since 8.004s ago] {'nationalities_id': None, 'nationalities': 'NP'}
# 2022-07-01 13:00:32,891 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:32,893 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:32,895 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:00:32,896 INFO sqlalchemy.engine.Engine [cached since 7.998s ago] {}
# 2022-07-01 13:00:32,904 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:32,905 INFO sqlalchemy.engine.Engine [cached since 7.992s ago] {'issuing_country_id_1': 'KE', 'issuing_country_id_2': '1. Trafficking in person contrary to section 3(1) (d) of counter trafficking in persons Act No. 8 of 2010.\r\n2. Fraudulent acquisition of travel doc ... (445 characters truncated) ...  Act No. 12 of 2011.\r\n6. Unlawfully being present in Kenya contrary to section 53(1)(j) of the Kenya Citizenship and Immigration Act No. 12 of 2011', 'param_1': 1}
# 2022-07-01 13:00:32,908 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:32,909 INFO sqlalchemy.engine.Engine [cached since 7.983s ago] {'charge_1': 'KE', 'charge_2': '1. Trafficking in person contrary to section 3(1) (d) of counter trafficking in persons Act No. 8 of 2010.\r\n2. Fraudulent acquisition of travel doc ... (445 characters truncated) ...  Act No. 12 of 2011.\r\n6. Unlawfully being present in Kenya contrary to section 53(1)(j) of the Kenya Citizenship and Immigration Act No. 12 of 2011', 'param_1': 1}
# 2022-07-01 13:00:32,913 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge_translation NOT IN (%(charge_translation_1)s, %(charge_translation_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:32,915 INFO sqlalchemy.engine.Engine [cached since 7.981s ago] {'charge_translation_1': 'KE', 'charge_translation_2': '1. Trafficking in person contrary to section 3(1) (d) of counter trafficking in persons Act No. 8 of 2010.\r\n2. Fraudulent acquisition of travel doc ... (445 characters truncated) ...  Act No. 12 of 2011.\r\n6. Unlawfully being present in Kenya contrary to section 53(1)(j) of the Kenya Citizenship and Immigration Act No. 12 of 2011', 'param_1': 1}
# 2022-07-01 13:00:32,917 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id", "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge", "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# 2022-07-01 13:00:32,918 INFO sqlalchemy.engine.Engine [cached since 7.979s ago] {}
# 2022-07-01 13:00:32,931 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_id NOT IN (%(picture_id_1_1)s, %(picture_id_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:32,932 INFO sqlalchemy.engine.Engine [cached since 7.973s ago] {'param_1': 1, 'picture_id_1_1': '62471167', 'picture_id_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-40936/images/62471167'}
# 2022-07-01 13:00:32,935 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_url NOT IN (%(picture_url_1_1)s, %(picture_url_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:32,936 INFO sqlalchemy.engine.Engine [cached since 7.968s ago] {'param_1': 1, 'picture_url_1_1': '62471167', 'picture_url_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-40936/images/62471167'}
# 2022-07-01 13:00:33,300 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-07-01 13:00:33,302 INFO sqlalchemy.engine.Engine [cached since 6.718s ago] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62471167.jpg"}
# 2022-07-01 13:00:33,306 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:33,308 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:33,309 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:00:33,310 INFO sqlalchemy.engine.Engine [cached since 6.717s ago] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2022-07-01 13:00:33,766 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:00:33,767 INFO sqlalchemy.engine.Engine [cached since 9.04s ago] {}
# 2022-07-01 13:00:33,772 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Languages".languages_id = "Interpol_Terorists".id)) AND ("Interpol_Languages".languages_spoken_ids NOT IN (%(languages_spoken_ids_1_1)s, %(languages_spoken_ids_1_2)s, %(languages_spoken_ids_1_3)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:33,772 INFO sqlalchemy.engine.Engine [cached since 9.023s ago] {'param_1': 1, 'languages_spoken_ids_1_1': 'HIN', 'languages_spoken_ids_1_2': 'ENG', 'languages_spoken_ids_1_3': 'NEP'}
# 2022-07-01 13:00:33,775 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-07-01 13:00:33,775 INFO sqlalchemy.engine.Engine [cached since 9.006s ago] {'languages_id': None, 'languages_spoken_ids': 'HIN'}
# 2022-07-01 13:00:33,777 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:33,779 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:33,781 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# 2022-07-01 13:00:33,782 INFO sqlalchemy.engine.Engine [cached since 8.989s ago] {}
# 2022-07-01 13:00:33,790 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:33,792 INFO sqlalchemy.engine.Engine [cached since 8.915s ago] {'param_1': 1, 'nationalities_1_1': 'NP'}
# 2022-07-01 13:00:33,795 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:00:33,796 INFO sqlalchemy.engine.Engine [cached since 8.911s ago] {'nationalities_id': None, 'nationalities': 'NP'}
# 2022-07-01 13:00:33,799 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:00:33,802 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:00:33,804 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:00:33,805 INFO sqlalchemy.engine.Engine [cached since 8.909s ago] {}
# 2022-07-01 13:00:33,820 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:33,822 INFO sqlalchemy.engine.Engine [cached since 8.909s ago] {'issuing_country_id_1': 'KE', 'issuing_country_id_2': '1. Trafficking in persons contrary to section 3(1)(d) of the counter trafficking in person Act No. 8 of 2010.\r\n2. Fraudulent acquisition of travel  ... (452 characters truncated) ...  Act No.12 of 2011.\r\n6. Unlawfully being present in Kenya contrary to section 53(1)(j) of the Kenya Citizenship and Immigration Act No. 12 of 2011.', 'param_1': 1}
# 2022-07-01 13:00:33,825 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:00:33,827 INFO sqlalchemy.engine.Engine [cached since 8.901s ago] {'charge_1': 'KE', 'charge_2': '1. Trafficking in persons contrary to section 3(1)(d) of the counter trafficking in person Act No. 8 of 2010.\r\n2. Fraudulent acquisition of travel  ... (452 characters truncated) ...  Act No.12 of 2011.\r\n6. Unlawfully being present in Kenya contrary to section 53(1)(j) of the Kenya Citizenship and Immigration Act No. 12 of 2011.', 'param_1': 1}
# ...
# 2022-07-01 13:03:09,849 INFO sqlalchemy.engine.Engine [cached since 163.3s ago] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62379210.jpg"}
# 2022-07-01 13:03:09,884 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:03:09,903 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:03:09,908 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:03:09,912 INFO sqlalchemy.engine.Engine [cached since 163.3s ago] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2022-07-01 13:03:10,530 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:03:10,532 INFO sqlalchemy.engine.Engine [cached since 165.8s ago] {}
# 2022-07-01 13:03:10,560 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Languages".languages_id = "Interpol_Terorists".id)) AND ("Interpol_Languages".languages_spoken_ids NOT IN (%(languages_spoken_ids_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:10,561 INFO sqlalchemy.engine.Engine [cached since 165.8s ago] {'param_1': 1, 'languages_spoken_ids_1_1': 'RUS'}
# 2022-07-01 13:03:10,569 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-07-01 13:03:10,571 INFO sqlalchemy.engine.Engine [cached since 165.8s ago] {'languages_id': None, 'languages_spoken_ids': 'RUS'}
# 2022-07-01 13:03:10,574 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:03:10,576 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:03:10,578 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# 2022-07-01 13:03:10,579 INFO sqlalchemy.engine.Engine [cached since 165.8s ago] {}
# 2022-07-01 13:03:10,592 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:10,594 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {'param_1': 1, 'nationalities_1_1': 'RU'}
# 2022-07-01 13:03:10,602 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:03:10,603 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {'nationalities_id': None, 'nationalities': 'RU'}
# 2022-07-01 13:03:10,606 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:03:10,608 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:03:10,610 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:03:10,611 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {}
# 2022-07-01 13:03:10,622 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:10,623 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {'issuing_country_id_1': 'RU', 'issuing_country_id_2': 'participation in the activity of a terrorist organization; participation in the activity of an illegal armed formation;', 'param_1': 1}
# 2022-07-01 13:03:10,633 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:10,634 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {'charge_1': 'RU', 'charge_2': 'participation in the activity of a terrorist organization; participation in the activity of an illegal armed formation;', 'param_1': 1}
# 2022-07-01 13:03:10,637 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge_translation NOT IN (%(charge_translation_1)s, %(charge_translation_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:10,639 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {'charge_translation_1': 'RU', 'charge_translation_2': 'participation in the activity of a terrorist organization; participation in the activity of an illegal armed formation;', 'param_1': 1}
# 2022-07-01 13:03:10,642 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id", "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge", "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# 2022-07-01 13:03:10,643 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {}
# 2022-07-01 13:03:10,661 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_id NOT IN (%(picture_id_1_1)s, %(picture_id_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:10,662 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {'param_1': 1, 'picture_id_1_1': '62356998', 'picture_id_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-7519/images/62356998'}
# 2022-07-01 13:03:10,666 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_url NOT IN (%(picture_url_1_1)s, %(picture_url_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:10,667 INFO sqlalchemy.engine.Engine [cached since 165.7s ago] {'param_1': 1, 'picture_url_1_1': '62356998', 'picture_url_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-7519/images/62356998'}
# 2022-07-01 13:03:10,951 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-07-01 13:03:10,952 INFO sqlalchemy.engine.Engine [cached since 164.4s ago] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62356998.jpg"}
# 2022-07-01 13:03:10,955 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:03:10,957 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:03:10,958 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:03:10,959 INFO sqlalchemy.engine.Engine [cached since 164.4s ago] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2022-07-01 13:03:11,485 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-07-01 13:03:11,486 INFO sqlalchemy.engine.Engine [cached since 166.8s ago] {}
# 2022-07-01 13:03:11,493 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Languages".languages_id = "Interpol_Terorists".id)) AND ("Interpol_Languages".languages_spoken_ids NOT IN (%(languages_spoken_ids_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:11,495 INFO sqlalchemy.engine.Engine [cached since 166.7s ago] {'param_1': 1, 'languages_spoken_ids_1_1': 'RUS'}
# 2022-07-01 13:03:11,497 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-07-01 13:03:11,499 INFO sqlalchemy.engine.Engine [cached since 166.7s ago] {'languages_id': None, 'languages_spoken_ids': 'RUS'}
# 2022-07-01 13:03:11,501 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:03:11,504 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:03:11,505 INFO sqlalchemy.engine.Engine SELECT "Interpol_Languages".languages_spoken_ids AS "Interpol_Languages_languages_spoken_ids"
# FROM "Interpol_Languages"
# 2022-07-01 13:03:11,506 INFO sqlalchemy.engine.Engine [cached since 166.7s ago] {}
# 2022-07-01 13:03:15,206 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Nations".nationalities_id = "Interpol_Terorists".id)) AND ("Interpol_Nations".nationalities NOT IN (%(nationalities_1_1)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:15,238 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {'param_1': 1, 'nationalities_1_1': 'RU'}
# 2022-07-01 13:03:15,289 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-07-01 13:03:15,290 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {'nationalities_id': None, 'nationalities': 'RU'}
# 2022-07-01 13:03:15,301 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:03:15,307 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:03:15,308 INFO sqlalchemy.engine.Engine SELECT "Interpol_Nations".nationalities AS "Interpol_Nations_nationalities"
# FROM "Interpol_Nations"
# 2022-07-01 13:03:15,309 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {}
# 2022-07-01 13:03:15,324 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".issuing_country_id NOT IN (%(issuing_country_id_1)s, %(issuing_country_id_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:15,325 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {'issuing_country_id_1': 'RU', 'issuing_country_id_2': 'Organization of activity of the terrorist organization and participation in activity of such organization.\r\nParticipation in the illegal armed formations.', 'param_1': 1}
# 2022-07-01 13:03:15,333 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge NOT IN (%(charge_1)s, %(charge_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:15,334 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {'charge_1': 'RU', 'charge_2': 'Organization of activity of the terrorist organization and participation in activity of such organization.\r\nParticipation in the illegal armed formations.', 'param_1': 1}
# 2022-07-01 13:03:15,338 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpolarrest_Warrants".arrest_warrants_id = "Interpol_Terorists".id)) AND ("Interpolarrest_Warrants".charge_translation NOT IN (%(charge_translation_1)s, %(charge_translation_2)s, NULL))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:15,339 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {'charge_translation_1': 'RU', 'charge_translation_2': 'Organization of activity of the terrorist organization and participation in activity of such organization.\r\nParticipation in the illegal armed formations.', 'param_1': 1}
# 2022-07-01 13:03:15,342 INFO sqlalchemy.engine.Engine SELECT "Interpolarrest_Warrants".issuing_country_id AS "Interpolarrest_Warrants_issuing_country_id", "Interpolarrest_Warrants".charge AS "Interpolarrest_Warrants_charge", "Interpolarrest_Warrants".charge_translation AS "Interpolarrest_Warrants_charge_translation"
# FROM "Interpolarrest_Warrants"
# 2022-07-01 13:03:15,344 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {}
# 2022-07-01 13:03:15,363 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_id NOT IN (%(picture_id_1_1)s, %(picture_id_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:15,364 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {'param_1': 1, 'picture_id_1_1': '62346271', 'picture_id_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-4555/images/62346271'}
# 2022-07-01 13:03:15,370 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# WHERE (EXISTS (SELECT *
# FROM "Interpol_Terorists"
# WHERE "Interpol_Teror_Images".images_id = "Interpol_Terorists".id)) AND ("Interpol_Teror_Images".picture_url NOT IN (%(picture_url_1_1)s, %(picture_url_1_2)s))
#  LIMIT %(param_1)s
# 2022-07-01 13:03:15,371 INFO sqlalchemy.engine.Engine [cached since 170.4s ago] {'param_1': 1, 'picture_url_1_1': '62346271', 'picture_url_1_2': 'https://ws-public.interpol.int/notices/v1/red/2022-4555/images/62346271'}
# 2022-07-01 13:03:15,968 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-07-01 13:03:15,969 INFO sqlalchemy.engine.Engine [cached since 169.4s ago] {'images_id': None, 'picture_id': '6', 'picture_url': '2', 'images_file': "https://ws-public.interpol.int/notices/v1/red/['2', '0', '2', '2', '/', '4', '9', '7', '5']/images/62346271.jpg"}
# 2022-07-01 13:03:15,975 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-01 13:03:15,978 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 13:03:15,980 INFO sqlalchemy.engine.Engine SELECT "Interpol_Teror_Images".picture_id AS "Interpol_Teror_Images_picture_id", "Interpol_Teror_Images".picture_url AS "Interpol_Teror_Images_picture_url"
# FROM "Interpol_Teror_Images"
# 2022-07-01 13:03:15,981 INFO sqlalchemy.engine.Engine [cached since 169.4s ago] {}
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
# %run imports.ipynb
# %run INTERPOL_CREATE.ipynb
import import_ipynb
import imports
import INTERPOL_CREATE
# Out:
# Requirement already satisfied: marshmallow-sqlalchemy in c:\programdata\anaconda3\lib\site-packages (0.28.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: SQLAlchemy>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow-sqlalchemy) (1.4.22)
# Requirement already satisfied: marshmallow>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow-sqlalchemy) (3.17.0)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow>=3.0.0->marshmallow-sqlalchemy) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow>=3.0.0->marshmallow-sqlalchemy) (3.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy>=1.3.0->marshmallow-sqlalchemy) (1.1.1)
# Requirement already satisfied: flask-marshmallow in c:\programdata\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: marshmallow>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from flask-marshmallow) (3.17.0)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from flask-marshmallow) (1.16.0)
# Requirement already satisfied: Flask in c:\programdata\anaconda3\lib\site-packages (from flask-marshmallow) (1.1.2)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow>=2.0.0->flask-marshmallow) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow>=2.0.0->flask-marshmallow) (3.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from Flask->flask-marshmallow) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from Flask->flask-marshmallow) (2.0.2)
# Requirement already satisfied: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from Flask->flask-marshmallow) (8.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask->flask-marshmallow) (2.0.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=5.1->Flask->flask-marshmallow) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask->flask-marshmallow) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Users table added to python_app database.
# Users table added to python_app database.
# Users table added to python_app database.
# Users table added to python_app database.
# Users table added to python_app database.
# 2022-07-01 12:59:58,592 INFO sqlalchemy.engine.Engine select version()
# 2022-07-01 12:59:58,593 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-01 12:59:58,596 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-07-01 12:59:58,597 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-01 12:59:58,599 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-07-01 12:59:58,600 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-01 12:59:58,602 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-01 12:59:58,604 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-01 12:59:58,605 INFO sqlalchemy.engine.Engine [generated in 0.00096s] {'name': 'Interpol_Terorists'}
# 2022-07-01 12:59:58,610 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-01 12:59:58,611 INFO sqlalchemy.engine.Engine [cached since 0.007105s ago] {'name': 'Interpol_Languages'}
# 2022-07-01 12:59:58,614 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-01 12:59:58,614 INFO sqlalchemy.engine.Engine [cached since 0.01023s ago] {'name': 'Interpol_Nations'}
# 2022-07-01 12:59:58,617 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-01 12:59:58,618 INFO sqlalchemy.engine.Engine [cached since 0.01383s ago] {'name': 'Interpolarrest_Warrants'}
# 2022-07-01 12:59:58,620 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-01 12:59:58,621 INFO sqlalchemy.engine.Engine [cached since 0.017s ago] {'name': 'Interpol_Teror_Images'}
# 2022-07-01 12:59:58,623 INFO sqlalchemy.engine.Engine COMMIT
# Requirement already satisfied: marshmallow-sqlalchemy in c:\programdata\anaconda3\lib\site-packages (0.28.0)
# Requirement already satisfied: marshmallow>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow-sqlalchemy) (3.17.0)
# Requirement already satisfied: SQLAlchemy>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow-sqlalchemy) (1.4.22)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow>=3.0.0->marshmallow-sqlalchemy) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow>=3.0.0->marshmallow-sqlalchemy) (3.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy>=1.3.0->marshmallow-sqlalchemy) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: flask-marshmallow in c:\programdata\anaconda3\lib\site-packages (0.14.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from flask-marshmallow) (1.16.0)
#
# Requirement already satisfied: marshmallow>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from flask-marshmallow) (3.17.0)
# Requirement already satisfied: Flask in c:\programdata\anaconda3\lib\site-packages (from flask-marshmallow) (1.1.2)
# Requirement already satisfied: packaging>=17.0 in c:\programdata\anaconda3\lib\site-packages (from marshmallow>=2.0.0->flask-marshmallow) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow>=2.0.0->flask-marshmallow) (3.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask->flask-marshmallow) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from Flask->flask-marshmallow) (2.0.2)
# Requirement already satisfied: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from Flask->flask-marshmallow) (8.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from Flask->flask-marshmallow) (2.11.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=5.1->Flask->flask-marshmallow) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask->flask-marshmallow) (1.1.1)
# importing Jupyter notebook from imports.ipynb
# Traceback (most recent call last):
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\yasem\AppData\Local\Temp/ipykernel_15580/1813769767.py", line 3, in <module>
#     import imports
#
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#
#   File "<frozen importlib._bootstrap>", line 664, in _load_unlocked
#
#   File "<frozen importlib._bootstrap>", line 627, in _load_backward_compatible
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\import_ipynb.py", line 61, in load_module
#     exec(code, mod.__dict__)
#
#   File "<string>", line 1
#     pip install marshmallow-sqlalchemy
#         ^
# SyntaxError: invalid syntax
# Traceback (most recent call last):
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\yasem\AppData\Local\Temp/ipykernel_15580/4278750199.py", line 2, in <module>
#     get_ipython().run_line_magic('run', 'INTERPOL_CREATE.ipynb')
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2351, in run_line_magic
#     result = fn(*args, **kwargs)
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\decorator.py", line 232, in fun
#     return caller(func, *(extras + args), **kw)
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\execution.py", line 724, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2838, in safe_execfile_ipy
#     result.raise_error()
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 332, in raise_error
#     raise self.error_in_exec
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\yasem\AppData\Local\Temp/ipykernel_15580/1813769767.py", line 3, in <module>
#     import imports
#
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#
#   File "<frozen importlib._bootstrap>", line 664, in _load_unlocked
#
#   File "<frozen importlib._bootstrap>", line 627, in _load_backward_compatible
#
#   File "c:\ProgramData\Anaconda3\lib\site-packages\import_ipynb.py", line 61, in load_module
#     exec(code, mod.__dict__)
#
#   File "<string>", line 1
#     pip install marshmallow-sqlalchemy
#         ^
# SyntaxError: invalid syntax
