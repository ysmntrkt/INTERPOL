# %%
import requests
import os 
import json
from sqlalchemy_utils import database_exists, create_database
import psycopg2
from sqlalchemy.dialects import postgresql
from sqlalchemy import create_engine,Table, Column, String, MetaData,Integer,Date,Numeric,Boolean,ForeignKey,TEXT,VARBINARY,VARCHAR,DATE,DECIMAL,BIGINT
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship,aliased,backref,sessionmaker

# %%
def get_request(url):
    payload={}
    headers = {}
    return requests.request("GET", url, headers=headers, data=payload)
def createFile(img_id):
     fileName = str(img_id)
     img_path_ıd= str(img_path)
     mainFile = f'https://ws-public.interpol.int/notices/v1/red/{img_path_ıd}/images'
     pictureFile = mainFile + '/' + fileName + '.jpg'
     return pictureFile
def Downloads(file_Path,file_Url):
     with open(os.path.join(r'file_Path'), 'wb') as f:
        response = requests.get(file_Url, stream=False)
        if not response.ok:
            print(response)
        for block in response.iter_content(1024):
            if not block:
                break
            f.write(block)               
def ımg_path_query():
     for i in s.query(Terrorists.entity_id).all():
        img_path=i[0]
        img_path=map(str,img_path)
        return img_path

# %%
Base = declarative_base()

class Terrorists(Base):
    __tablename__ = 'Interpol_Terorists'
    id = Column(Integer, primary_key=True)
    forename = Column(VARCHAR)
    sex_id = Column(VARCHAR(3))
    date_of_birth = Column(DATE)
    place_of_birt= Column(VARCHAR)
    country_of_birth_id =Column(VARCHAR)
    weight=Column(DECIMAL)
    height=Column(DECIMAL)
    distinguishing_marks =Column(TEXT)
    eyes_colors_id=Column(VARCHAR)
    hairs_id=Column(VARCHAR)
    entity_id=Column(VARCHAR)
    print("Users table added to python_app database.")

    def __init__(self,forename,sex_id,date_of_birth,place_of_birth,country_of_birth_id,weight,height,distinguishing_marks,eyes_colors_id,hairs_id,entity_id):
      self.forename=forename
      self.sex_id=sex_id
      self.date_of_birth=date_of_birth
      self.place_of_birt=place_of_birth
      self.country_of_birth_id=country_of_birth_id
      self.weight=weight
      self.height=height
      self.distinguishing_marks=distinguishing_marks
      self.eyes_colors_id=eyes_colors_id
      self.hairs_id=hairs_id
      self.entity_id=entity_id
    
class languages(Base):
      __tablename__ = 'Interpol_Languages'
      id = Column(Integer, primary_key=True,autoincrement=True)
      languages_id = Column(BIGINT, ForeignKey('Interpol_Terorists.id'))
      languages_spoken_ids= Column(VARCHAR(30))
      terrorists=relationship("Terrorists",backref=backref('Interpol_Languages')) 
      print("Users table added to python_app database.")

      def __init__(self, languages_spoken_ids):
             self.languages_spoken_ids=languages_spoken_ids
                
class Nations(Base):
    __tablename__ = 'Interpol_Nations'
    id = Column(Integer, primary_key=True,autoincrement=True)
    nationalities_id=Column(BIGINT, ForeignKey('Interpol_Terorists.id'))
    nationalities=Column(VARCHAR(15))
    terrorists=relationship("Terrorists", backref=backref('Interpol_Nations')) 
    print("Users table added to python_app database.")
    def __init__(self, nationalities):
             self.nationalities=nationalities

class Warrants(Base):
    __tablename__ = 'Interpolarrest_Warrants'
    id = Column(Integer, primary_key=True,autoincrement=True)
    arrest_warrants_id=Column(BIGINT, ForeignKey('Interpol_Terorists.id'))
    issuing_country_id=Column(VARCHAR(10))
    charge=Column(TEXT)
    charge_translation=Column(TEXT)
    terrorists=relationship("Terrorists", backref=backref('Interpolarrest_Warrants'))
    print("Users table added to python_app database.")

    def __init__(self, issuing_country_id,charge,charge_translation):
          self.issuing_country_id= issuing_country_id
          self.charge=charge
          self.charge_translation=charge_translation

class Photo(Base):
    __tablename__ = 'Interpol_Teror_Images'
    id = Column(Integer, primary_key=True,autoincrement=True)
    images_id=Column(BIGINT, ForeignKey('Interpol_Terorists.id'))
    picture_id =Column(VARCHAR(20))
    picture_url=Column(VARCHAR)
    images_file = Column(TEXT)
    terrorists=relationship("Terrorists", backref=backref('Interpol_Teror_Images')) 
    print("Users table added to python_app database.")

    def __init__(self,picture_id,picture_url,images_file):
          self.picture_id= picture_id
          self.picture_url=picture_url
          self.images_file=images_file             

if __name__=="__main__":
 engine = create_engine('postgresql+psycopg2://postgres:1111@localhost:5432/arananlar1_db',encoding='utf-8-sig', echo=True)
 Session = sessionmaker(bind=engine)
 Base.metadata.create_all(engine) 
 s = Session()
# Out:
# Users table added to python_app database.
# Users table added to python_app database.
# Users table added to python_app database.
# Users table added to python_app database.
# Users table added to python_app database.
# 2022-06-15 14:08:41,499 INFO sqlalchemy.engine.Engine select version()
# 2022-06-15 14:08:41,500 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-06-15 14:08:41,503 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-06-15 14:08:41,504 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-06-15 14:08:41,506 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-06-15 14:08:41,507 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-06-15 14:08:41,510 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:41,512 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-06-15 14:08:41,513 INFO sqlalchemy.engine.Engine [generated in 0.00123s] {'name': 'Interpol_Terorists'}
# 2022-06-15 14:08:41,517 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-06-15 14:08:41,518 INFO sqlalchemy.engine.Engine [cached since 0.006169s ago] {'name': 'Interpol_Languages'}
# 2022-06-15 14:08:41,520 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-06-15 14:08:41,521 INFO sqlalchemy.engine.Engine [cached since 0.009097s ago] {'name': 'Interpol_Nations'}
# 2022-06-15 14:08:41,523 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-06-15 14:08:41,524 INFO sqlalchemy.engine.Engine [cached since 0.01196s ago] {'name': 'Interpolarrest_Warrants'}
# 2022-06-15 14:08:41,526 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-06-15 14:08:41,527 INFO sqlalchemy.engine.Engine [cached since 0.01484s ago] {'name': 'Interpol_Teror_Images'}
# 2022-06-15 14:08:41,530 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Interpol_Terorists" (
# 	id SERIAL NOT NULL,
# 	forename VARCHAR,
# 	sex_id VARCHAR(3),
# 	date_of_birth DATE,
# 	place_of_birt VARCHAR,
# 	country_of_birth_id VARCHAR,
# 	weight DECIMAL,
# 	height DECIMAL,
# 	distinguishing_marks TEXT,
# 	eyes_colors_id VARCHAR,
# 	hairs_id VARCHAR,
# 	entity_id VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2022-06-15 14:08:41,531 INFO sqlalchemy.engine.Engine [no key 0.00092s] {}
# 2022-06-15 14:08:41,558 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Interpol_Languages" (
# 	id SERIAL NOT NULL,
# 	languages_id BIGINT,
# 	languages_spoken_ids VARCHAR(30),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(languages_id) REFERENCES "Interpol_Terorists" (id)
# )
#
#
# 2022-06-15 14:08:41,559 INFO sqlalchemy.engine.Engine [no key 0.00107s] {}
# 2022-06-15 14:08:41,577 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Interpol_Nations" (
# 	id SERIAL NOT NULL,
# 	nationalities_id BIGINT,
# 	nationalities VARCHAR(15),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(nationalities_id) REFERENCES "Interpol_Terorists" (id)
# )
#
#
# 2022-06-15 14:08:41,578 INFO sqlalchemy.engine.Engine [no key 0.00115s] {}
# 2022-06-15 14:08:41,591 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Interpolarrest_Warrants" (
# 	id SERIAL NOT NULL,
# 	arrest_warrants_id BIGINT,
# 	issuing_country_id VARCHAR(10),
# 	charge TEXT,
# 	charge_translation TEXT,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(arrest_warrants_id) REFERENCES "Interpol_Terorists" (id)
# )
#
#
# 2022-06-15 14:08:41,592 INFO sqlalchemy.engine.Engine [no key 0.00094s] {}
# 2022-06-15 14:08:41,613 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Interpol_Teror_Images" (
# 	id SERIAL NOT NULL,
# 	images_id BIGINT,
# 	picture_id VARCHAR(20),
# 	picture_url VARCHAR,
# 	images_file TEXT,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(images_id) REFERENCES "Interpol_Terorists" (id)
# )
#
#
# 2022-06-15 14:08:41,615 INFO sqlalchemy.engine.Engine [no key 0.00117s] {}
# 2022-06-15 14:08:41,636 INFO sqlalchemy.engine.Engine COMMIT

# %%
response = get_request("https://ws-public.interpol.int/notices/v1/red?resultPerPage=20&page=1")
max_page = int(response.json()['total']/20)
for i in range (1,max_page):
    old_page = response.json()['query']['page']
    url = f"https://ws-public.interpol.int/notices/v1/red?resultPerPage=20&page={i}"
    response = get_request(url)
    new_page = response.json()['query']['page']
    if old_page == new_page and old_page > 1:
        break
    page = len(response.json()['_embedded']['notices'])
    for j in range(0,page):
            person_url = response.json()['_embedded']['notices'][j]['_links']['self']['href']
            ImageUrl =  response.json()['_embedded']['notices'][j]['_links']['images']['href']
            response_person = get_request(person_url)
            response_images= get_request(ImageUrl)
            forename =response_person.json()['forename']
            sex_id =response_person.json()['sex_id']
            date_of_birth =response_person.json()['date_of_birth'] 
            place_of_birt= response_person.json()['place_of_birth']
            country=response_person.json()['country_of_birth_id']
            weight=response_person.json()['weight']
            height=response_person.json()['height']
            distinguishing_marks =response_person.json()['distinguishing_marks']
            eyes_colors_id=str(response_person.json()['eyes_colors_id'])
            hairs_id=str(response_person.json()['hairs_id'])
            entity_id=response_person.json()['entity_id']
            data=Terrorists(forename, sex_id,date_of_birth, place_of_birt,country, weight,height,distinguishing_marks,eyes_colors_id,hairs_id,entity_id )
            for k in  response_person.json()['languages_spoken_ids'] or []:
             data1=languages(k)
             data.Interpol_Languages.append(data1)
            for j in response_person.json()['nationalities'] or []:
                data2=Nations(j)
                data.Interpol_Nations.append(data2)
            for a in  response_person.json()['arrest_warrants']:
                issuing_country_id = a['issuing_country_id']
                charge = a['charge']
                charge_translation = a['charge_translation']
                data3= Warrants(issuing_country_id,charge,charge_translation)
                data.Interpolarrest_Warrants.append(data3)
                img_path=ımg_path_query()  
            for v in response_images.json()['_embedded']['images']:
                img_id=v['picture_id']
                img=v['_links']['self']['href']
                picturesFile = createFile(img_id)
                picturesDownload=Downloads(picturesFile,img) 
                data_4= Photo(img_id ,img, picturesFile)
                data.Interpol_Teror_Images.append(data_4)
                s.add(data)
                s.add(data1)
                s.add(data2)
                s.add(data3)
                s.add(data_4)
            try:
             s.commit()
            except:
             s.rollback()
            finally:
             s.close()
             print("Connection to python_app database has now been closed")
# Out:
# 2022-06-15 14:08:46,272 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:46,275 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:46,277 INFO sqlalchemy.engine.Engine [generated in 0.00142s] {}
# 2022-06-15 14:08:46,725 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:08:46,726 INFO sqlalchemy.engine.Engine [generated in 0.00086s] {'forename': 'AIDAR', 'sex_id': 'M', 'date_of_birth': '1978/02/22', 'place_of_birt': 'UCHALINSKIY DOISTRICT, AKHUNOVO SETTLEMENT', 'country_of_birth_id': 'RU', 'weight': 0, 'height': 0, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/4975'}
# 2022-06-15 14:08:46,731 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:08:46,732 INFO sqlalchemy.engine.Engine [generated in 0.00095s] {'nationalities_id': 1, 'nationalities': 'RU'}
# 2022-06-15 14:08:46,737 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:08:46,738 INFO sqlalchemy.engine.Engine [generated in 0.00103s] ({'images_id': 1, 'picture_id': '62347684', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-4975/images/62347684', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/None/images/62347684.jpg'}, {'images_id': 1, 'picture_id': '62347686', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-4975/images/62347686', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/None/images/62347686.jpg'})
# 2022-06-15 14:08:46,746 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:08:46,747 INFO sqlalchemy.engine.Engine [generated in 0.00107s] {'arrest_warrants_id': 1, 'issuing_country_id': 'RU', 'charge': 'participation in activities of an illegal armed formation', 'charge_translation': None}
# 2022-06-15 14:08:46,752 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:08:46,753 INFO sqlalchemy.engine.Engine [generated in 0.00090s] ({'languages_id': 1, 'languages_spoken_ids': 'TAT'}, {'languages_id': 1, 'languages_spoken_ids': 'RUS'})
# 2022-06-15 14:08:46,758 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:08:47,339 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:47,340 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:47,341 INFO sqlalchemy.engine.Engine [cached since 1.065s ago] {}
# 2022-06-15 14:08:47,343 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:47,344 INFO sqlalchemy.engine.Engine [cached since 1.069s ago] {}
# 2022-06-15 14:08:49,056 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:08:49,057 INFO sqlalchemy.engine.Engine [cached since 2.331s ago] {'forename': 'SATINDERJEET', 'sex_id': 'M', 'date_of_birth': '1994/03/11', 'place_of_birt': 'SHRI MUKTSAR SAHIB, PUNJAB', 'country_of_birth_id': 'IN', 'weight': 100, 'height': 1.75, 'distinguishing_marks': None, 'eyes_colors_id': "['BLA']", 'hairs_id': "['BLA']", 'entity_id': '2022/35371'}
# 2022-06-15 14:08:49,059 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:08:49,060 INFO sqlalchemy.engine.Engine [cached since 2.329s ago] {'nationalities_id': 2, 'nationalities': 'IN'}
# 2022-06-15 14:08:49,064 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:08:49,065 INFO sqlalchemy.engine.Engine [generated in 0.00112s] {'images_id': 2, 'picture_id': '62462229', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-35371/images/62462229', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3999520>/images/62462229.jpg'}
# 2022-06-15 14:08:49,069 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:08:49,069 INFO sqlalchemy.engine.Engine [generated in 0.00095s] ({'arrest_warrants_id': 2, 'issuing_country_id': 'IN', 'charge': 'Attempt to murder, criminal conspiracy @ Supply of illegal Firearms', 'charge_translation': None}, {'arrest_warrants_id': 2, 'issuing_country_id': 'IN', 'charge': 'Murder, Criminal Conspiracy & Supply of illegal Firearms', 'charge_translation': None})
# 2022-06-15 14:08:49,072 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:08:49,073 INFO sqlalchemy.engine.Engine [cached since 2.321s ago] ({'languages_id': 2, 'languages_spoken_ids': 'ENG'}, {'languages_id': 2, 'languages_spoken_ids': 'HIN'}, {'languages_id': 2, 'languages_spoken_ids': 'PAN'})
# 2022-06-15 14:08:49,076 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:08:50,823 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:50,824 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:50,825 INFO sqlalchemy.engine.Engine [cached since 4.551s ago] {}
# 2022-06-15 14:08:50,828 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:50,829 INFO sqlalchemy.engine.Engine [cached since 4.555s ago] {}
# 2022-06-15 14:08:50,832 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:50,833 INFO sqlalchemy.engine.Engine [cached since 4.559s ago] {}
# 2022-06-15 14:08:51,367 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:08:51,367 INFO sqlalchemy.engine.Engine [cached since 4.643s ago] {'forename': 'HARWINDER SINGH', 'sex_id': 'M', 'date_of_birth': '1990', 'place_of_birt': 'KHADOOR SAHIB, PUNJAB', 'country_of_birth_id': 'IN', 'weight': 70, 'height': 1.7, 'distinguishing_marks': 'OLD INJURY MARK ON LEFT KNEE.', 'eyes_colors_id': "['BLA']", 'hairs_id': "['BLA']", 'entity_id': '2022/29937'}
# 2022-06-15 14:08:51,374 INFO sqlalchemy.engine.Engine ROLLBACK
# Connection to python_app database has now been closed
# 2022-06-15 14:08:52,230 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:52,232 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:52,233 INFO sqlalchemy.engine.Engine [cached since 5.957s ago] {}
# 2022-06-15 14:08:52,234 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:08:52,709 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:52,710 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:52,710 INFO sqlalchemy.engine.Engine [cached since 6.435s ago] {}
# 2022-06-15 14:08:52,993 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:08:52,994 INFO sqlalchemy.engine.Engine [generated in 0.00084s] ({'forename': 'KAMIL KRZYSZTOF', 'sex_id': 'M', 'date_of_birth': '1987/08/02', 'place_of_birt': 'JASTRZEBIE ZDROJ', 'country_of_birth_id': None, 'weight': 75, 'height': 1.75, 'distinguishing_marks': 'Weight about 75 kg, slim figure, height 175-180 cm; tattoo with “LOGO” FC BARCELONA SPORTS CLUB, dark hair can be dyed in light blonde, brown eye', 'eyes_colors_id': "['BRO']", 'hairs_id': 'None', 'entity_id': '2022/34805'}, {'forename': 'MANUEL JOSE', 'sex_id': 'M', 'date_of_birth': '1967/10/20', 'place_of_birt': None, 'country_of_birth_id': 'US', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/35500'})
# 2022-06-15 14:08:52,997 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:08:52,998 INFO sqlalchemy.engine.Engine [generated in 0.00144s] ({'nationalities_id': 3, 'nationalities': 'PL'}, {'nationalities_id': 4, 'nationalities': 'US'})
# 2022-06-15 14:08:53,001 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:08:53,002 INFO sqlalchemy.engine.Engine [cached since 3.938s ago] {'images_id': 3, 'picture_id': '62449941', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-34805/images/62449941', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B19B80>/images/62449941.jpg'}
# 2022-06-15 14:08:53,004 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:08:53,005 INFO sqlalchemy.engine.Engine [cached since 3.937s ago] ({'arrest_warrants_id': 3, 'issuing_country_id': 'PL', 'charge': 'Murder, grievous bodily injury; acquire information not to be intended', 'charge_translation': None}, {'arrest_warrants_id': 4, 'issuing_country_id': 'GT', 'charge': 'AGRESION SEXUAL CON AGRAVACION DE LA PENA', 'charge_translation': None})
# 2022-06-15 14:08:53,008 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:08:53,009 INFO sqlalchemy.engine.Engine [cached since 6.258s ago] ({'languages_id': 4, 'languages_spoken_ids': 'ENG'}, {'languages_id': 4, 'languages_spoken_ids': 'SPA'})
# 2022-06-15 14:08:53,011 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:08:53,478 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:53,479 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:53,480 INFO sqlalchemy.engine.Engine [cached since 7.205s ago] {}
# 2022-06-15 14:08:53,736 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:08:53,736 INFO sqlalchemy.engine.Engine [cached since 7.011s ago] {'forename': 'HENRY JONATAN', 'sex_id': 'M', 'date_of_birth': '1977/04/02', 'place_of_birt': None, 'country_of_birth_id': 'UY', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/32019'}
# 2022-06-15 14:08:53,738 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:08:53,739 INFO sqlalchemy.engine.Engine [cached since 7.008s ago] {'nationalities_id': 5, 'nationalities': 'UY'}
# 2022-06-15 14:08:53,741 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:08:53,742 INFO sqlalchemy.engine.Engine [cached since 4.678s ago] {'images_id': 5, 'picture_id': '62446136', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-32019/images/62446136', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B19FD0>/images/62446136.jpg'}
# 2022-06-15 14:08:53,744 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:08:53,746 INFO sqlalchemy.engine.Engine [cached since 7s ago] {'arrest_warrants_id': 5, 'issuing_country_id': 'BR', 'charge': 'Aggravated theft', 'charge_translation': None}
# 2022-06-15 14:08:53,749 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:08:53,750 INFO sqlalchemy.engine.Engine [cached since 6.998s ago] ({'languages_id': 5, 'languages_spoken_ids': 'POR'}, {'languages_id': 5, 'languages_spoken_ids': 'SPA'})
# 2022-06-15 14:08:53,752 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:08:54,217 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:54,218 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:54,219 INFO sqlalchemy.engine.Engine [cached since 7.944s ago] {}
# 2022-06-15 14:08:55,263 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:08:55,264 INFO sqlalchemy.engine.Engine [cached since 8.538s ago] {'forename': 'GUSTAVO FABIAN', 'sex_id': 'M', 'date_of_birth': '1970/07/17', 'place_of_birt': None, 'country_of_birth_id': 'AR', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/32793'}
# 2022-06-15 14:08:55,266 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:08:55,267 INFO sqlalchemy.engine.Engine [cached since 8.535s ago] {'nationalities_id': 6, 'nationalities': 'AR'}
# 2022-06-15 14:08:55,269 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:08:55,269 INFO sqlalchemy.engine.Engine [cached since 8.532s ago] ({'images_id': 6, 'picture_id': '62443281', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-32793/images/62443281', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3AB7DC0>/images/62443281.jpg'}, {'images_id': 6, 'picture_id': '62443283', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-32793/images/62443283', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3AB7DC0>/images/62443283.jpg'}, {'images_id': 6, 'picture_id': '62443285', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-32793/images/62443285', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3AB7DC0>/images/62443285.jpg'}, {'images_id': 6, 'picture_id': '62443412', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-32793/images/62443412', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3AB7DC0>/images/62443412.jpg'})
# 2022-06-15 14:08:55,271 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:08:55,272 INFO sqlalchemy.engine.Engine [cached since 8.525s ago] {'arrest_warrants_id': 6, 'issuing_country_id': 'AR', 'charge': 'HOMICIDIO AGRAVADO POR EL USO DE ARMA DE FUEGO', 'charge_translation': None}
# 2022-06-15 14:08:55,274 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:08:55,275 INFO sqlalchemy.engine.Engine [generated in 0.00094s] {'languages_id': 6, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:08:55,277 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:08:55,760 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:55,762 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:55,763 INFO sqlalchemy.engine.Engine [cached since 9.489s ago] {}
# 2022-06-15 14:08:56,796 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:08:56,797 INFO sqlalchemy.engine.Engine [cached since 10.07s ago] {'forename': 'MUKHABBAT', 'sex_id': 'M', 'date_of_birth': '1991/08/03', 'place_of_birt': None, 'country_of_birth_id': 'TJ', 'weight': 0, 'height': 1.75, 'distinguishing_marks': None, 'eyes_colors_id': "['BRO']", 'hairs_id': "['OTHD']", 'entity_id': '2022/31603'}
# 2022-06-15 14:08:56,799 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:08:56,800 INFO sqlalchemy.engine.Engine [cached since 10.07s ago] {'nationalities_id': 7, 'nationalities': 'TJ'}
# 2022-06-15 14:08:56,802 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:08:56,803 INFO sqlalchemy.engine.Engine [cached since 10.07s ago] ({'images_id': 7, 'picture_id': '62439872', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-31603/images/62439872', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B19580>/images/62439872.jpg'}, {'images_id': 7, 'picture_id': '62439874', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-31603/images/62439874', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B19580>/images/62439874.jpg'}, {'images_id': 7, 'picture_id': '62439876', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-31603/images/62439876', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B19580>/images/62439876.jpg'}, {'images_id': 7, 'picture_id': '62439878', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-31603/images/62439878', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B19580>/images/62439878.jpg'})
# 2022-06-15 14:08:56,806 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:08:56,807 INFO sqlalchemy.engine.Engine [cached since 10.06s ago] {'arrest_warrants_id': 7, 'issuing_country_id': 'RU', 'charge': 'getting trained with the aim of terrorist activity; participation in a terrorist organization', 'charge_translation': None}
# 2022-06-15 14:08:56,809 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:08:56,810 INFO sqlalchemy.engine.Engine [cached since 10.06s ago] ({'languages_id': 7, 'languages_spoken_ids': 'RUS'}, {'languages_id': 7, 'languages_spoken_ids': 'ARA'}, {'languages_id': 7, 'languages_spoken_ids': 'TGK'})
# 2022-06-15 14:08:56,813 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:08:57,400 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:08:57,401 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:08:57,402 INFO sqlalchemy.engine.Engine [cached since 11.13s ago] {}
# 2022-06-15 14:08:58,489 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:08:58,490 INFO sqlalchemy.engine.Engine [cached since 11.76s ago] {'forename': 'TAMARA', 'sex_id': 'F', 'date_of_birth': '1975/04/23', 'place_of_birt': 'PARIS 19EME', 'country_of_birth_id': 'FR', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/30281'}
# 2022-06-15 14:08:58,492 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:08:58,493 INFO sqlalchemy.engine.Engine [cached since 11.76s ago] {'nationalities_id': 8, 'nationalities': 'FR'}
# 2022-06-15 14:08:58,496 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:08:58,497 INFO sqlalchemy.engine.Engine [cached since 9.433s ago] {'images_id': 8, 'picture_id': '62435802', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-30281/images/62435802', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E398E760>/images/62435802.jpg'}
# 2022-06-15 14:08:58,499 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:08:58,500 INFO sqlalchemy.engine.Engine [cached since 11.75s ago] {'arrest_warrants_id': 8, 'issuing_country_id': 'FR', 'charge': "- SOUSTRACTION D'ENFANT PAR ASCENDANT\r\n- NON REPRESENTATION D'ENFANT", 'charge_translation': None}
# 2022-06-15 14:08:58,501 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:08:58,502 INFO sqlalchemy.engine.Engine [cached since 3.229s ago] {'languages_id': 8, 'languages_spoken_ids': 'FRE'}
# 2022-06-15 14:08:58,505 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:09:00,770 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:09:00,771 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:09:00,771 INFO sqlalchemy.engine.Engine [cached since 14.5s ago] {}
# 2022-06-15 14:09:01,500 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:09:01,500 INFO sqlalchemy.engine.Engine [cached since 14.78s ago] {'forename': 'JORGE MARCELO', 'sex_id': 'M', 'date_of_birth': '1976/12/07', 'place_of_birt': None, 'country_of_birth_id': None, 'weight': None, 'height': None, 'distinguishing_marks': 'tez trigueña', 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/30714'}
# 2022-06-15 14:09:01,502 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:09:01,503 INFO sqlalchemy.engine.Engine [cached since 14.77s ago] {'nationalities_id': 9, 'nationalities': 'UY'}
# 2022-06-15 14:09:01,505 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:09:01,506 INFO sqlalchemy.engine.Engine [cached since 12.44s ago] {'images_id': 9, 'picture_id': '62440875', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-30714/images/62440875', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3999430>/images/62440875.jpg'}
# 2022-06-15 14:09:01,508 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:09:01,510 INFO sqlalchemy.engine.Engine [cached since 14.76s ago] {'arrest_warrants_id': 9, 'issuing_country_id': 'UY', 'charge': 'Un Delito continuaado de Importación y Comerzalización de Estupefacientes agravado por haberse cometido por un grupo Organizado.', 'charge_translation': None}
# 2022-06-15 14:09:01,512 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:09:01,514 INFO sqlalchemy.engine.Engine [cached since 6.241s ago] {'languages_id': 9, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:09:01,517 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:09:03,318 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:09:03,319 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:09:03,319 INFO sqlalchemy.engine.Engine [cached since 17.04s ago] {}
# 2022-06-15 14:09:03,622 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:09:03,623 INFO sqlalchemy.engine.Engine [cached since 16.9s ago] {'forename': 'LESTER ABIMAEL', 'sex_id': 'M', 'date_of_birth': '2002/05/12', 'place_of_birt': 'VILLA NUEVA', 'country_of_birth_id': 'GT', 'weight': 90, 'height': 1.68, 'distinguishing_marks': 'no se le observan', 'eyes_colors_id': "['BLA']", 'hairs_id': "['BLA']", 'entity_id': '2022/31350'}
# 2022-06-15 14:09:03,624 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:09:03,625 INFO sqlalchemy.engine.Engine [cached since 16.89s ago] {'nationalities_id': 10, 'nationalities': 'GT'}
# 2022-06-15 14:09:03,627 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:09:03,628 INFO sqlalchemy.engine.Engine [cached since 14.56s ago] {'images_id': 10, 'picture_id': '62439146', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-31350/images/62439146', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3993880>/images/62439146.jpg'}
# 2022-06-15 14:09:03,630 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:09:03,632 INFO sqlalchemy.engine.Engine [cached since 16.89s ago] {'arrest_warrants_id': 10, 'issuing_country_id': 'GT', 'charge': 'FEMICIDIO', 'charge_translation': None}
# 2022-06-15 14:09:03,634 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:09:03,635 INFO sqlalchemy.engine.Engine [cached since 8.361s ago] {'languages_id': 10, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:09:03,637 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:09:04,115 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:09:04,116 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:09:04,117 INFO sqlalchemy.engine.Engine [cached since 17.84s ago] {}
# 2022-06-15 14:09:04,649 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:09:04,650 INFO sqlalchemy.engine.Engine [cached since 17.93s ago] {'forename': 'MOHAMED', 'sex_id': 'M', 'date_of_birth': '1979/12/11', 'place_of_birt': 'VOORBURG', 'country_of_birth_id': 'NL', 'weight': 0, 'height': 0, 'distinguishing_marks': 'NYABI possibly has tattoos on his right groin and left upper arm. Possibly the word " MARTHA". he has a scar on his right eyebrow and a mole on his collarbone.', 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/29541'}
# 2022-06-15 14:09:04,652 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:09:04,654 INFO sqlalchemy.engine.Engine [cached since 17.92s ago] {'nationalities_id': 11, 'nationalities': 'NL'}
# 2022-06-15 14:09:04,656 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:09:04,658 INFO sqlalchemy.engine.Engine [cached since 17.92s ago] ({'images_id': 11, 'picture_id': '62452047', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-29541/images/62452047', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3993B20>/images/62452047.jpg'}, {'images_id': 11, 'picture_id': '62452049', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-29541/images/62452049', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3993B20>/images/62452049.jpg'})
# 2022-06-15 14:09:04,660 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:09:04,661 INFO sqlalchemy.engine.Engine [cached since 17.92s ago] {'arrest_warrants_id': 11, 'issuing_country_id': 'NL', 'charge': 'participation in a criminal organisation, illicit trafficking in narcotic, drugs, psychotropic substances, kidnapping, illegal restraint and hostage-taking, prohibited possession of weapons', 'charge_translation': None}
# 2022-06-15 14:09:04,664 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:09:04,665 INFO sqlalchemy.engine.Engine [cached since 17.91s ago] ({'languages_id': 11, 'languages_spoken_ids': 'DUT'}, {'languages_id': 11, 'languages_spoken_ids': 'ENG'})
# 2022-06-15 14:09:04,668 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:09:05,149 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:09:05,150 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:09:05,151 INFO sqlalchemy.engine.Engine [cached since 18.88s ago] {}
# 2022-06-15 14:09:05,446 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:09:05,447 INFO sqlalchemy.engine.Engine [cached since 18.72s ago] {'forename': 'ROLLER BRANDON', 'sex_id': 'M', 'date_of_birth': '1993/03/13', 'place_of_birt': 'CUILAPA, SANTA ROSA', 'country_of_birth_id': 'GT', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/29933'}
# 2022-06-15 14:09:05,449 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:09:05,450 INFO sqlalchemy.engine.Engine [cached since 18.72s ago] {'nationalities_id': 12, 'nationalities': 'GT'}
# 2022-06-15 14:09:05,452 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:09:05,453 INFO sqlalchemy.engine.Engine [cached since 16.39s ago] {'images_id': 12, 'picture_id': '62434716', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-29933/images/62434716', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3999AF0>/images/62434716.jpg'}
# 2022-06-15 14:09:05,455 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:09:05,456 INFO sqlalchemy.engine.Engine [cached since 18.71s ago] {'arrest_warrants_id': 12, 'issuing_country_id': 'GT', 'charge': 'ASESINATO', 'charge_translation': None}
# 2022-06-15 14:09:05,458 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:09:05,459 INFO sqlalchemy.engine.Engine [cached since 10.19s ago] {'languages_id': 12, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:09:05,461 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:09:05,981 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:09:05,983 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:09:05,984 INFO sqlalchemy.engine.Engine [cached since 19.71s ago] {}
# 2022-06-15 14:09:06,300 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:09:06,301 INFO sqlalchemy.engine.Engine [cached since 19.58s ago] {'forename': 'JORGE MARIO', 'sex_id': 'M', 'date_of_birth': '1973/04/30', 'place_of_birt': 'CUILAPA, SANTA ROSA', 'country_of_birth_id': 'GT', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/29929'}
# 2022-06-15 14:09:06,302 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:09:06,303 INFO sqlalchemy.engine.Engine [cached since 19.57s ago] {'nationalities_id': 13, 'nationalities': 'GT'}
# 2022-06-15 14:09:06,305 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:09:06,306 INFO sqlalchemy.engine.Engine [cached since 17.24s ago] {'images_id': 13, 'picture_id': '62434709', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-29929/images/62434709', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3AB7C40>/images/62434709.jpg'}
# 2022-06-15 14:09:06,308 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:09:06,310 INFO sqlalchemy.engine.Engine [cached since 19.56s ago] {'arrest_warrants_id': 13, 'issuing_country_id': 'GT', 'charge': 'COMPLICE DE ASESINATO', 'charge_translation': None}
# 2022-06-15 14:09:06,311 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:09:06,314 INFO sqlalchemy.engine.Engine [cached since 11.04s ago] {'languages_id': 13, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:09:06,316 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:09:06,816 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:09:06,817 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:09:06,817 INFO sqlalchemy.engine.Engine [cached since 20.54s ago] {}
# 2022-06-15 14:09:07,063 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:09:07,064 INFO sqlalchemy.engine.Engine [cached since 20.34s ago] {'forename': 'AXEL LAUTARO', 'sex_id': 'M', 'date_of_birth': '1998/06/04', 'place_of_birt': None, 'country_of_birth_id': 'AR', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/29157'}
# 2022-06-15 14:09:07,066 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:09:07,067 INFO sqlalchemy.engine.Engine [cached since 20.34s ago] {'nationalities_id': 14, 'nationalities': 'AR'}
# 2022-06-15 14:09:07,068 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:09:07,069 INFO sqlalchemy.engine.Engine [cached since 18.01s ago] {'images_id': 14, 'picture_id': '62432052', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-29157/images/62432052', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3999AF0>/images/62432052.jpg'}
# 2022-06-15 14:09:07,071 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:09:07,071 INFO sqlalchemy.engine.Engine [cached since 20.32s ago] {'arrest_warrants_id': 14, 'issuing_country_id': 'AR', 'charge': 'HOMICIDIO', 'charge_translation': None}
# 2022-06-15 14:09:07,073 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:09:07,074 INFO sqlalchemy.engine.Engine [cached since 11.8s ago] {'languages_id': 14, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:09:07,076 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:09:10,030 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:09:10,031 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:09:10,032 INFO sqlalchemy.engine.Engine [cached since 23.76s ago] {}
# 2022-06-15 14:09:10,574 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:09:10,575 INFO sqlalchemy.engine.Engine [cached since 23.85s ago] {'forename': 'JHONY MERARDO', 'sex_id': 'M', 'date_of_birth': '1984/10/25', 'place_of_birt': 'CIUDAD DE TRUJILLO', 'country_of_birth_id': 'PE', 'weight': 0, 'height': 0, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2022/28451'}
# 2022-06-15 14:09:10,577 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:09:10,577 INFO sqlalchemy.engine.Engine [cached since 23.85s ago] {'nationalities_id': 15, 'nationalities': 'PE'}
# 2022-06-15 14:09:10,580 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:09:10,581 INFO sqlalchemy.engine.Engine [cached since 21.52s ago] {'images_id': 15, 'picture_id': '62429595', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2022-28451/images/62429595', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E398E640>/images/62429595.jpg'}
# 2022-06-15 14:09:10,583 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:09:10,585 INFO sqlalchemy.engine.Engine [cached since 23.84s ago] {'arrest_warrants_id': 15, 'issuing_country_id': 'AR', 'charge': 'LESIONES GRAVES', 'charge_translation': None}
# 2022-06-15 14:09:10,588 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:09:10,589 INFO sqlalchemy.engine.Engine [cached since 15.32s ago] {'languages_id': 15, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:09:10,592 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:09:13,344 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...
# 2022-06-15 14:12:25,283 INFO sqlalchemy.engine.Engine [cached since 218.6s ago] {'nationalities_id': 151, 'nationalities': 'RU'}
# 2022-06-15 14:12:25,285 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:12:25,286 INFO sqlalchemy.engine.Engine [cached since 216.2s ago] {'images_id': 151, 'picture_id': '62322478', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2021-82146/images/62322478', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B39280>/images/62322478.jpg'}
# 2022-06-15 14:12:25,288 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:12:25,290 INFO sqlalchemy.engine.Engine [cached since 218.5s ago] {'arrest_warrants_id': 151, 'issuing_country_id': 'RU', 'charge': 'Organization of activity of the terrorist organization and participation in activity of such organization.', 'charge_translation': None}
# 2022-06-15 14:12:25,292 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:12:25,293 INFO sqlalchemy.engine.Engine [cached since 210s ago] {'languages_id': 151, 'languages_spoken_ids': 'RUS'}
# 2022-06-15 14:12:25,295 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:12:25,794 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:12:25,795 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:12:25,796 INFO sqlalchemy.engine.Engine [cached since 219.5s ago] {}
# 2022-06-15 14:12:26,043 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:12:26,044 INFO sqlalchemy.engine.Engine [cached since 219.3s ago] {'forename': 'NARCISO', 'sex_id': 'M', 'date_of_birth': '1981/07/28', 'place_of_birt': 'CAPITAN BADO', 'country_of_birth_id': 'PY', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2021/79994'}
# 2022-06-15 14:12:26,045 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:12:26,046 INFO sqlalchemy.engine.Engine [cached since 217s ago] {'images_id': 152, 'picture_id': '62315393', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2021-79994/images/62315393', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3AB7C40>/images/62315393.jpg'}
# 2022-06-15 14:12:26,048 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:12:26,049 INFO sqlalchemy.engine.Engine [cached since 219.3s ago] {'arrest_warrants_id': 152, 'issuing_country_id': 'PY', 'charge': 'HECHO PUNIBLE DE LAVADO DE DINERO\r\nHECHO PUNIBLE DE ASOCIACION CRIMINAL', 'charge_translation': None}
# 2022-06-15 14:12:26,051 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:12:26,568 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:12:26,569 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:12:26,570 INFO sqlalchemy.engine.Engine [cached since 220.3s ago] {}
# 2022-06-15 14:12:26,807 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:12:26,808 INFO sqlalchemy.engine.Engine [cached since 220.1s ago] {'forename': 'DIDIER RAMON', 'sex_id': 'M', 'date_of_birth': '1982/09/20', 'place_of_birt': 'SALTO DEL GUAIRA', 'country_of_birth_id': 'PY', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2021/80006'}
# 2022-06-15 14:12:26,811 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:12:26,812 INFO sqlalchemy.engine.Engine [cached since 217.7s ago] {'images_id': 153, 'picture_id': '62315419', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2021-80006/images/62315419', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B330A0>/images/62315419.jpg'}
# 2022-06-15 14:12:26,814 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:12:26,815 INFO sqlalchemy.engine.Engine [cached since 220.1s ago] {'arrest_warrants_id': 153, 'issuing_country_id': 'PY', 'charge': 'HECHO PUNIBLE DE LAVADO DE DINERO\r\nHECHO PUNIBLE DE ASOCIACION CRIMINAL', 'charge_translation': None}
# 2022-06-15 14:12:26,817 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:12:26,818 INFO sqlalchemy.engine.Engine [cached since 211.5s ago] {'languages_id': 153, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:12:26,820 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:12:27,312 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:12:27,313 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:12:27,313 INFO sqlalchemy.engine.Engine [cached since 221s ago] {}
# 2022-06-15 14:12:28,861 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:12:28,862 INFO sqlalchemy.engine.Engine [cached since 222.1s ago] {'forename': 'JOSÉ ENMANUEL', 'sex_id': 'M', 'date_of_birth': '1989/12/08', 'place_of_birt': 'San Miguel', 'country_of_birth_id': 'SV', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2021/79966'}
# 2022-06-15 14:12:28,864 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:12:28,865 INFO sqlalchemy.engine.Engine [cached since 222.1s ago] {'nationalities_id': 154, 'nationalities': 'SV'}
# 2022-06-15 14:12:28,866 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:12:28,867 INFO sqlalchemy.engine.Engine [cached since 219.8s ago] {'images_id': 154, 'picture_id': '62315314', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2021-79966/images/62315314', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B27CD0>/images/62315314.jpg'}
# 2022-06-15 14:12:28,869 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:12:28,870 INFO sqlalchemy.engine.Engine [cached since 222.1s ago] {'arrest_warrants_id': 154, 'issuing_country_id': 'SV', 'charge': 'Organizaciones Terroristas, Homicidio Agravado y Extorsión Agravada', 'charge_translation': None}
# 2022-06-15 14:12:28,874 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:12:28,875 INFO sqlalchemy.engine.Engine [cached since 213.6s ago] {'languages_id': 154, 'languages_spoken_ids': 'SPA'}
# 2022-06-15 14:12:28,876 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:12:32,383 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:12:32,384 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:12:32,385 INFO sqlalchemy.engine.Engine [cached since 226.1s ago] {}
# 2022-06-15 14:12:32,868 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:12:32,869 INFO sqlalchemy.engine.Engine [cached since 226.1s ago] {'forename': 'ADEL', 'sex_id': 'M', 'date_of_birth': '1991/05/13', 'place_of_birt': 'SARAJEVO', 'country_of_birth_id': 'BA', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2021/81051'}
# 2022-06-15 14:12:32,872 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:12:32,873 INFO sqlalchemy.engine.Engine [cached since 226.1s ago] {'nationalities_id': 155, 'nationalities': 'BA'}
# 2022-06-15 14:12:32,875 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:12:32,876 INFO sqlalchemy.engine.Engine [cached since 223.8s ago] {'images_id': 155, 'picture_id': '62318579', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2021-81051/images/62318579', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E3B3ABB0>/images/62318579.jpg'}
# 2022-06-15 14:12:32,877 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:12:32,878 INFO sqlalchemy.engine.Engine [cached since 226.1s ago] {'arrest_warrants_id': 155, 'issuing_country_id': 'BA', 'charge': 'MURDER', 'charge_translation': None}
# 2022-06-15 14:12:32,880 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:12:32,881 INFO sqlalchemy.engine.Engine [cached since 217.6s ago] {'languages_id': 155, 'languages_spoken_ids': 'BOS'}
# 2022-06-15 14:12:32,883 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
# 2022-06-15 14:12:33,407 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-15 14:12:33,408 INFO sqlalchemy.engine.Engine SELECT "Interpol_Terorists".entity_id AS "Interpol_Terorists_entity_id"
# FROM "Interpol_Terorists"
# 2022-06-15 14:12:33,409 INFO sqlalchemy.engine.Engine [cached since 227.1s ago] {}
# 2022-06-15 14:12:33,765 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Terorists" (forename, sex_id, date_of_birth, place_of_birt, country_of_birth_id, weight, height, distinguishing_marks, eyes_colors_id, hairs_id, entity_id) VALUES (%(forename)s, %(sex_id)s, %(date_of_birth)s, %(place_of_birt)s, %(country_of_birth_id)s, %(weight)s, %(height)s, %(distinguishing_marks)s, %(eyes_colors_id)s, %(hairs_id)s, %(entity_id)s) RETURNING "Interpol_Terorists".id
# 2022-06-15 14:12:33,766 INFO sqlalchemy.engine.Engine [cached since 227s ago] {'forename': 'KHADIZHAT', 'sex_id': 'F', 'date_of_birth': '1980/04/03', 'place_of_birt': 'MAKHACHKALA TOWN, DAGESTAN REPUBLIC', 'country_of_birth_id': 'RU', 'weight': None, 'height': None, 'distinguishing_marks': None, 'eyes_colors_id': 'None', 'hairs_id': 'None', 'entity_id': '2021/80938'}
# 2022-06-15 14:12:33,768 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Nations" (nationalities_id, nationalities) VALUES (%(nationalities_id)s, %(nationalities)s) RETURNING "Interpol_Nations".id
# 2022-06-15 14:12:33,768 INFO sqlalchemy.engine.Engine [cached since 227s ago] {'nationalities_id': 156, 'nationalities': 'RU'}
# 2022-06-15 14:12:33,770 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Teror_Images" (images_id, picture_id, picture_url, images_file) VALUES (%(images_id)s, %(picture_id)s, %(picture_url)s, %(images_file)s) RETURNING "Interpol_Teror_Images".id
# 2022-06-15 14:12:33,770 INFO sqlalchemy.engine.Engine [cached since 224.7s ago] {'images_id': 156, 'picture_id': '62318213', 'picture_url': 'https://ws-public.interpol.int/notices/v1/red/2021-80938/images/62318213', 'images_file': 'https://ws-public.interpol.int/notices/v1/red/<map object at 0x000001D8E39998E0>/images/62318213.jpg'}
# 2022-06-15 14:12:33,772 INFO sqlalchemy.engine.Engine INSERT INTO "Interpolarrest_Warrants" (arrest_warrants_id, issuing_country_id, charge, charge_translation) VALUES (%(arrest_warrants_id)s, %(issuing_country_id)s, %(charge)s, %(charge_translation)s) RETURNING "Interpolarrest_Warrants".id
# 2022-06-15 14:12:33,774 INFO sqlalchemy.engine.Engine [cached since 227s ago] {'arrest_warrants_id': 156, 'issuing_country_id': 'RU', 'charge': 'Organization of activity of the terrorist organization and participation in activity of such organization. Participation in illegal armed formation.', 'charge_translation': None}
# 2022-06-15 14:12:33,776 INFO sqlalchemy.engine.Engine INSERT INTO "Interpol_Languages" (languages_id, languages_spoken_ids) VALUES (%(languages_id)s, %(languages_spoken_ids)s) RETURNING "Interpol_Languages".id
# 2022-06-15 14:12:33,777 INFO sqlalchemy.engine.Engine [cached since 218.5s ago] {'languages_id': 156, 'languages_spoken_ids': 'RUS'}
# 2022-06-15 14:12:33,779 INFO sqlalchemy.engine.Engine COMMIT
# Connection to python_app database has now been closed
